# %%
# Cell 1: Import libraries
import geopandas as gpd
import pandas as pd
import json
import os
import folium

# %%
# Cell 2: Create output directory
os.makedirs('staygis-blog/posts/2025-10-01-nigeria-65', exist_ok=True)

# %%
# Cell 3: Load Nigeria @65 data
data = {
    "type": "FeatureCollection",
    "features": [
        {
            "id": "0",
            "type": "Feature",
            "properties": {"city": "Lagos", "intensity_2023": 80},
            "geometry": {"type": "Point", "coordinates": [3.3792, 6.5244]}
        },
        {
            "id": "1",
            "type": "Feature",
            "properties": {"city": "Abuja", "intensity_2023": 65},
            "geometry": {"type": "Point", "coordinates": [7.4951, 9.0579]}
        },
        {
            "id": "2",
            "type": "Feature",
            "properties": {"city": "Kano", "intensity_2023": 70},
            "geometry": {"type": "Point", "coordinates": [8.5167, 12.0001]}
        }
    ]
}
df = pd.DataFrame([
    {
        'city': f['properties']['city'],
        'lon': f['geometry']['coordinates'][0],
        'lat': f['geometry']['coordinates'][1],
        'intensity_2023': f['properties']['intensity_2023']
    } for f in data['features']
])
df
# Out:
#     city     lon      lat  intensity_2023
# 0  Lagos  3.3792   6.5244              80
# 1  Abuja  7.4951   9.0579              65
# 2   Kano  8.5167  12.0001              70

# %%
# Cell 4: Create GeoDataFrame
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df['lon'], df['lat']),
    crs="EPSG:4326"
)
gdf
# Out:
#     city     lon      lat  intensity_2023                geometry
# 0  Lagos  3.3792   6.5244              80   POINT (3.3792 6.5244)
# 1  Abuja  7.4951   9.0579              65   POINT (7.4951 9.0579)
# 2   Kano  8.5167  12.0001              70  POINT (8.5167 12.0001)

# %%
# Cell 5: Preview Nigeria @65 map
m = folium.Map(location=[9.0820, 8.6753], zoom_start=6, tiles="OpenStreetMap")
for _, row in gdf.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius=row['intensity_2023'] / 10,
        color="#0f2d25",
        fill=True,
        fill_color="#008753",
        fill_opacity=0.7,
        popup=f"{row['city']}: Night Lights Intensity {row['intensity_2023']}"
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a43b8aae84db3680a2a7bcc0d63ad405 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a43b8aae84db3680a2a7bcc0d63ad405&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a43b8aae84db3680a2a7bcc0d63ad405 = L.map(
#                 &quot;map_a43b8aae84db3680a2a7bcc0d63ad405&quot;,
#                 {
#                     center: [9.082, 8.6753],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ed2d69af9fd5ed4e987a77858ff5fff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3ed2d69af9fd5ed4e987a77858ff5fff.addTo(map_a43b8aae84db3680a2a7bcc0d63ad405);
#
#
#             var circle_marker_b6dc57e4d2244dc692fba63787603a05 = L.circleMarker(
#                 [6.5244, 3.3792],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f2d25&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008753&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a43b8aae84db3680a2a7bcc0d63ad405);
#
#
#         var popup_1d4d31226a83ed039f33d6b0ff34445b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b8f51375f24dbca6f9d33a909f74ecc = $(`&lt;div id=&quot;html_2b8f51375f24dbca6f9d33a909f74ecc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lagos: Night Lights Intensity 80&lt;/div&gt;`)[0];
#                 popup_1d4d31226a83ed039f33d6b0ff34445b.setContent(html_2b8f51375f24dbca6f9d33a909f74ecc);
#
#
#
#         circle_marker_b6dc57e4d2244dc692fba63787603a05.bindPopup(popup_1d4d31226a83ed039f33d6b0ff34445b)
#         ;
#
#
#
#
#             var circle_marker_06fa9199bba137694a8b21361d90cb0f = L.circleMarker(
#                 [9.0579, 7.4951],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f2d25&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008753&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a43b8aae84db3680a2a7bcc0d63ad405);
#
#
#         var popup_61a274b920bed8c3891dd44f89919653 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85890f669cf6039c80c76303cde09d85 = $(`&lt;div id=&quot;html_85890f669cf6039c80c76303cde09d85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abuja: Night Lights Intensity 65&lt;/div&gt;`)[0];
#                 popup_61a274b920bed8c3891dd44f89919653.setContent(html_85890f669cf6039c80c76303cde09d85);
#
#
#
#         circle_marker_06fa9199bba137694a8b21361d90cb0f.bindPopup(popup_61a274b920bed8c3891dd44f89919653)
#         ;
#
#
#
#
#             var circle_marker_aacadc1628aa35eabdf7ba0fcabd1549 = L.circleMarker(
#                 [12.0001, 8.5167],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f2d25&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008753&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a43b8aae84db3680a2a7bcc0d63ad405);
#
#
#         var popup_b3e11adc56cf4aa17e70e680bfd1c59c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bf53e343cf8872662b5d8e0e1445259 = $(`&lt;div id=&quot;html_0bf53e343cf8872662b5d8e0e1445259&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kano: Night Lights Intensity 70&lt;/div&gt;`)[0];
#                 popup_b3e11adc56cf4aa17e70e680bfd1c59c.setContent(html_0bf53e343cf8872662b5d8e0e1445259);
#
#
#
#         circle_marker_aacadc1628aa35eabdf7ba0fcabd1549.bindPopup(popup_b3e11adc56cf4aa17e70e680bfd1c59c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Cell 6: Save GeoJSON
geojson = json.loads(gdf.to_json())  # Use to_json for compatibility
with open('staygis-blog/posts/2025-10-01-nigeria-65/nigeria-night-lights.json', 'w') as f:
    json.dump(geojson, f, indent=2)
print("GeoJSON saved to staygis-blog/posts/2025-10-01-nigeria-65/nigeria-night-lights.json")
# Out:
# GeoJSON saved to staygis-blog/posts/2025-10-01-nigeria-65/nigeria-night-lights.json
